# %%
# first what we call 'ck_test' - i.e. MLE timescales, 25 macrostates asked for, 24 macrostates out

# %%
import numpy as np

# %%
ls ck_test
# Out:
# 1000/            200/             run_hmm_1000.sh  run_hmm_200.sh
# 1100/            2000/            run_hmm_1100.sh  run_hmm_2000.sh
# 1200/            300/             run_hmm_1200.sh  run_hmm_300.sh
# 1300/            400/             run_hmm_1300.sh  run_hmm_400.sh
# 1400/            500/             run_hmm_1400.sh  run_hmm_500.sh
# 1500/            600/             run_hmm_1500.sh  run_hmm_600.sh
# 1600/            700/             run_hmm_1600.sh  run_hmm_700.sh
# 1700/            800/             run_hmm_1700.sh  run_hmm_800.sh
# 1800/            900/             run_hmm_1800.sh  run_hmm_900.sh
# 1900/            run_hmm.py       run_hmm_1900.sh

# %%
ls ck_test/*
# Out:
# ck_test/run_hmm.py       ck_test/run_hmm_1600.sh  ck_test/run_hmm_400.sh
# ck_test/run_hmm_1000.sh  ck_test/run_hmm_1700.sh  ck_test/run_hmm_500.sh
# ck_test/run_hmm_1100.sh  ck_test/run_hmm_1800.sh  ck_test/run_hmm_600.sh
# ck_test/run_hmm_1200.sh  ck_test/run_hmm_1900.sh  ck_test/run_hmm_700.sh
# ck_test/run_hmm_1300.sh  ck_test/run_hmm_200.sh   ck_test/run_hmm_800.sh
# ck_test/run_hmm_1400.sh  ck_test/run_hmm_2000.sh  ck_test/run_hmm_900.sh
# ck_test/run_hmm_1500.sh  ck_test/run_hmm_300.sh
#
# ck_test/1000:
#
# ck_test/1100:
#
# ck_test/1200:
#
# ck_test/1300:
#
# ck_test/1400:
#
# ck_test/1500:
#
# ck_test/1600:
#
# ck_test/1700:
#
# ck_test/1800:
#
# ck_test/1900:
# P.npy                          observation_probabilities.npy
# lifetimes.npy                  pi.npy
# metastable_memberships.npy     timescales.npy
# metastable_sets.npy
#
# ck_test/200:
# P.npy                          observation_probabilities.npy
# lifetimes.npy                  pi.npy
# metastable_memberships.npy     timescales.npy
# metastable_sets.npy
#
# ck_test/2000:
#
# ck_test/300:
# P.npy                          observation_probabilities.npy
# lifetimes.npy                  pi.npy
# metastable_memberships.npy     timescales.npy
# metastable_sets.npy
#
# ck_test/400:
#
# ck_test/500:
#
# ck_test/600:
#
# ck_test/700:
#
# ck_test/800:
#
# ck_test/900:

# %%
ck_test_200 = np.load('ck_test/200/timescales.npy')

# %%
ck_test_300 = np.load('ck_test/300/timescales.npy')

# %%
ck_test_200
# Out:
# array([ 88165.99372348,  43769.83142989,  43287.37586078,  22492.38279803,
#         17847.78433252,   9519.4239926 ,   8918.09522197,   8041.01372458,
#          6680.7981791 ,   6140.06811667,   4996.09168549,   4965.72093552,
#          4951.0164821 ,   4510.06045978,   4507.84836122,   3679.45919568,
#          3449.35490024,   3132.16568892,   3003.1555725 ,   2912.14273796,
#          2376.51884629,   1929.96095831,   1582.77781318])

# %%
ck_test_300
# Out:
# array([ 227787.31140883,   99505.26172229,   83978.45383639,
#          23900.81821801,   23221.33099574,   20157.03502852,
#          11179.19564125,   10333.54762081,    8819.07446107,
#           7564.68504236,    6729.45871619,    5492.70479203,
#           5399.19780187,    4799.70812617,    4459.87665305,
#           4184.78510215,    4107.95625774,    3476.11669739,
#           3336.79795875,    3078.17595376,    2243.66757068,
#           2010.1090224 ,    1753.94311106,    1115.0427215 ])

# %%
ls ../results/25/
# Out:
# P.npy                      observation_probabilities/
# lifetimes.npy              pi.npy
# metastable_memberships/    timescales.npy
# metastable_sets.npy

# %%
ck_test_100 = np.load('../results/25/timescales.npy')

# %%
ck_test_100
# Out:
# array([ 66565.55911655,  36750.77832783,  33032.93813893,  16234.00580836,
#          8770.918981  ,   8352.25678071,   6859.74513203,   6445.6821403 ,
#          5510.44449568,   4548.93373116,   4028.65543039,   3923.28169285,
#          3573.50111586,   3466.90355694,   3122.94448576,   2944.05318017,
#          2720.8920794 ,   2601.52271046,   2239.57468203,   2089.88847459,
#          2010.22772087,   1790.89627797,   1314.56604255])

# %%
ck_test_1900 = np.load('ck_test/1900/timescales.npy')

# %%
ck_test_1900
# Out:
# array([ 34145.78991124])

# %%
# plot this

# %%
timescales = []

for i in range(23):
    timescales.append([ck_test_100[i], ck_test_200[i], ck_test_300[i]])

# %%
timescales
# Out:
# [[66565.559116551492, 88165.993723475316, 227787.3114088334],
#  [36750.77832782895, 43769.831429892831, 99505.261722287207],
#  [33032.938138927733, 43287.375860778426, 83978.453836387605],
#  [16234.005808363567, 22492.382798034865, 23900.818218012038],
#  [8770.9189810028001, 17847.784332519499, 23221.330995743545],
#  [8352.2567807091382, 9519.4239926016799, 20157.035028518592],
#  [6859.7451320253604, 8918.0952219696082, 11179.195641251848],
#  [6445.6821402982196, 8041.0137245794022, 10333.547620807414],
#  [5510.4444956789548, 6680.798179097832, 8819.0744610727997],
#  [4548.9337311567151, 6140.0681166682034, 7564.6850423612077],
#  [4028.6554303879007, 4996.0916854868974, 6729.4587161886056],
#  [3923.2816928473485, 4965.7209355209925, 5492.7047920298282],
#  [3573.5011158571888, 4951.0164820976288, 5399.1978018654218],
#  [3466.9035569385032, 4510.0604597816091, 4799.7081261724579],
#  [3122.9444857647254, 4507.848361220771, 4459.8766530524545],
#  [2944.0531801725379, 3679.4591956822283, 4184.7851021470433],
#  [2720.8920794033338, 3449.3549002362765, 4107.9562577376537],
#  [2601.5227104648211, 3132.1656889203132, 3476.1166973941877],
#  [2239.5746820269214, 3003.155572495371, 3336.7979587455784],
#  [2089.8884745877349, 2912.1427379614865, 3078.1759537638886],
#  [2010.2277208725836, 2376.51884628877, 2243.6675706759165],
#  [1790.8962779698402, 1929.9609583127196, 2010.1090223962174],
#  [1314.5660425465417, 1582.7778131753325, 1753.9431110619689]]

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.figure(dpi=300)
for i in range(len(timescales)):
    plt.plot([100, 200, 300], timescales[i]) 
plt.xticks([100,200,300])
plt.xlabel('Lag time (steps, 0.5 ns / step)')
plt.ylabel('Timescale (steps, 0.5 ns / step)')
plt.show()

# %%
plt.figure(dpi=300)
for i in range(len(timescales)):
    plt.plot([100, 200, 300], timescales[i])
plt.xticks([100,200,300])
plt.xlabel('Lag time (steps, 0.5 ns / step)')
plt.ylabel('Timescale (steps, 0.5 ns / step)')
plt.yscale('log')
plt.show()

# %%
# ok look at Bayesian

# %%
ls bayes_ck_test/*
# Out:
# bayes_ck_test/run_hmm.py       bayes_ck_test/run_hmm_1900.sh
# bayes_ck_test/run_hmm_100.sh   bayes_ck_test/run_hmm_200.sh
# bayes_ck_test/run_hmm_1000.sh  bayes_ck_test/run_hmm_2000.sh
# bayes_ck_test/run_hmm_1100.sh  bayes_ck_test/run_hmm_300.sh
# bayes_ck_test/run_hmm_1200.sh  bayes_ck_test/run_hmm_400.sh
# bayes_ck_test/run_hmm_1300.sh  bayes_ck_test/run_hmm_500.sh
# bayes_ck_test/run_hmm_1400.sh  bayes_ck_test/run_hmm_600.sh
# bayes_ck_test/run_hmm_1500.sh  bayes_ck_test/run_hmm_700.sh
# bayes_ck_test/run_hmm_1600.sh  bayes_ck_test/run_hmm_800.sh
# bayes_ck_test/run_hmm_1700.sh  bayes_ck_test/run_hmm_900.sh
# bayes_ck_test/run_hmm_1800.sh
#
# bayes_ck_test/100:
# P.npy                          observation_probabilities.npy
# lifetimes.npy                  pi.npy
# metastable_memberships.npy     timescales.npy
# metastable_sets.npy
#
# bayes_ck_test/1000:
#
# bayes_ck_test/1100:
#
# bayes_ck_test/1200:
# P.npy                            metastable_sets_L.npy
# P_L.npy                          metastable_sets_R.npy
# P_R.npy                          observation_probabilities.npy
# lifetimes.npy                    observation_probabilities_L.npy
# lifetimes_L.npy                  observation_probabilities_R.npy
# lifetimes_R.npy                  pi.npy
# metastable_memberships.npy       pi_L.npy
# metastable_memberships_L.npy     pi_R.npy
# metastable_memberships_R.npy     timescales.npy
# metastable_sets.npy
#
# bayes_ck_test/1300:
# P.npy                            metastable_sets_L.npy
# P_L.npy                          metastable_sets_R.npy
# P_R.npy                          observation_probabilities.npy
# lifetimes.npy                    observation_probabilities_L.npy
# lifetimes_L.npy                  observation_probabilities_R.npy
# lifetimes_R.npy                  pi.npy
# metastable_memberships.npy       pi_L.npy
# metastable_memberships_L.npy     pi_R.npy
# metastable_memberships_R.npy     timescales.npy
# metastable_sets.npy
#
# bayes_ck_test/1400:
# P.npy                          observation_probabilities.npy
# lifetimes.npy                  pi.npy
# metastable_memberships.npy     timescales.npy
# metastable_sets.npy
#
# bayes_ck_test/1500:
#
# bayes_ck_test/1600:
#
# bayes_ck_test/1700:
# P.npy                            metastable_sets_L.npy
# P_L.npy                          metastable_sets_R.npy
# P_R.npy                          observation_probabilities.npy
# lifetimes.npy                    observation_probabilities_L.npy
# lifetimes_L.npy                  observation_probabilities_R.npy
# lifetimes_R.npy                  pi.npy
# metastable_memberships.npy       pi_L.npy
# metastable_memberships_L.npy     pi_R.npy
# metastable_memberships_R.npy     timescales.npy
# metastable_sets.npy
#
# bayes_ck_test/1800:
# P.npy                            metastable_sets_L.npy
# P_L.npy                          metastable_sets_R.npy
# P_R.npy                          observation_probabilities.npy
# lifetimes.npy                    observation_probabilities_L.npy
# lifetimes_L.npy                  observation_probabilities_R.npy
# lifetimes_R.npy                  pi.npy
# metastable_memberships.npy       pi_L.npy
# metastable_memberships_L.npy     pi_R.npy
# metastable_memberships_R.npy     timescales.npy
# metastable_sets.npy
#
# bayes_ck_test/1900:
#
# bayes_ck_test/200:
# P.npy                          observation_probabilities.npy
# lifetimes.npy                  pi.npy
# metastable_memberships.npy     timescales.npy
# metastable_sets.npy
#
# bayes_ck_test/2000:
#
# bayes_ck_test/300:
# P.npy                          observation_probabilities.npy
# lifetimes.npy                  pi.npy
# metastable_memberships.npy     timescales.npy
# metastable_sets.npy
#
# bayes_ck_test/400:
# P.npy                          observation_probabilities.npy
# lifetimes.npy                  pi.npy
# metastable_memberships.npy     timescales.npy
# metastable_sets.npy
#
# bayes_ck_test/500:
# P.npy                          observation_probabilities.npy
# lifetimes.npy                  pi.npy
# metastable_memberships.npy     timescales.npy
# metastable_sets.npy
#
# bayes_ck_test/600:
# P.npy                          observation_probabilities.npy
# lifetimes.npy                  pi.npy
# metastable_memberships.npy     timescales.npy
# metastable_sets.npy
#
# bayes_ck_test/700:
#
# bayes_ck_test/800:
# P.npy                          observation_probabilities.npy
# lifetimes.npy                  pi.npy
# metastable_memberships.npy     timescales.npy
# metastable_sets.npy
#
# bayes_ck_test/900:
# P.npy                          observation_probabilities.npy
# lifetimes.npy                  pi.npy
# metastable_memberships.npy     timescales.npy
# metastable_sets.npy

# %%
b_ck_test_300 = np.load('bayes_ck_test/300/timescales.npy')

# %%
b_ck_test_300
# Out:
# array([ 110675.3070217 ,   58964.06327813,   33628.9678128 ,
#          27415.69501925,   23045.52475137,   17926.49994693,
#          14525.80105529,   13358.22690702,   11271.40771436,
#           7560.62695416,    5894.90698663,    5813.84372082,
#           5406.58372182,    5097.11687325,    4221.48019851,
#           3291.80292988,    3189.79015368,    2811.74870129,
#           1996.67497684,    1808.55062912,    1238.03524008])

# %%
# ok so this looks good - there's a lot of results here so let's loop over everything

# %%
lags = np.arange(100, 2100, 100)

# %%
timescales = []

for i in range(23):
    timescales.append([])

for lag in lags:
    try:
        timescales_ = np.load('bayes_ck_test/%d/timescales.npy' % lag)
        for i in range(23):
            try:
                timescales[i].append(timescales_[i])
            except IndexError:
                timescales[i].append(np.nan)
    except FileNotFoundError:
        for i in range(23):
            timescales[i].append(np.nan)

# %%
timescales
# Out:
# [[63273.814555169956,
#   93955.414662383439,
#   110675.30702169611,
#   250470.10766778406,
#   1975414.4914748571,
#   139418.71571576849,
#   nan,
#   37618.409050836948,
#   10284.779408248556,
#   nan,
#   nan,
#   nan,
#   nan,
#   9872.0461205715073,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [31642.510020643513,
#   48248.549009522874,
#   58964.063278133333,
#   193666.54835898342,
#   102166.9037821254,
#   30410.413045022913,
#   nan,
#   267.57183145047344,
#   4789.7729358088609,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [28002.184118202091,
#   44750.061421451013,
#   33628.967812798801,
#   51418.110064260916,
#   5866.9907802181169,
#   8417.7881655692308,
#   nan,
#   nan,
#   4063.2962721506919,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [16025.413337754368,
#   16670.069826858355,
#   27415.695019251227,
#   23056.791217066337,
#   4162.2030113771389,
#   2733.4470468499021,
#   nan,
#   nan,
#   2582.3919329813425,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [15352.434574802668,
#   10266.071947987688,
#   23045.524751366909,
#   16573.090989752818,
#   2452.2620394314981,
#   1389.830185996193,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [13271.808088414607,
#   8504.1540580722085,
#   17926.499946930016,
#   15745.853177294603,
#   1349.1542722979445,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [7918.0050356738511,
#   7746.0578984062586,
#   14525.801055292093,
#   12504.032511007841,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [5909.3944715856624,
#   6937.3984057214057,
#   13358.226907015396,
#   10606.696498121732,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [5460.2867444839294,
#   6573.1341824237934,
#   11271.407714357647,
#   9941.2383457895266,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [4495.5773486706385,
#   5928.8236375442493,
#   7560.6269541649526,
#   7655.1909045339844,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [3967.6705885677175,
#   5623.7435393999331,
#   5894.9069866307236,
#   7523.5839667095788,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [3704.1381738270493,
#   5366.7368242235452,
#   5813.8437208164814,
#   6093.8112560578702,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [3606.1734150241637,
#   4985.3979861063654,
#   5406.58372182332,
#   5852.0640337083332,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [3544.4909584698962,
#   4459.671057048181,
#   5097.1168732478709,
#   4042.5378057356525,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [3141.6577080917864,
#   4443.7321213985715,
#   4221.4801985052818,
#   4035.5118771157636,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [2674.1714271972664,
#   4061.0776421633473,
#   3291.8029298843189,
#   3454.9300475676587,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [2558.3669748018224,
#   3468.079235550782,
#   3189.7901536832642,
#   2958.3579913160556,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [2388.1097507299291,
#   3317.9641459938721,
#   2811.7487012920792,
#   2816.0402667604249,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [2113.4040871537482,
#   3252.726933350134,
#   1996.6749768365646,
#   1982.8525855491362,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [1931.3105294457212,
#   2525.0035820394983,
#   1808.5506291249142,
#   1635.5261493565108,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [1763.3524979575327,
#   1896.5032470942365,
#   1238.0352400762845,
#   1132.5819221663062,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [1120.3726086310653,
#   1309.7371556946298,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [854.43364572734288,
#   1273.2733298823009,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan]]

# %%
plt.figure(dpi=300)
for i in range(len(timescales)):
    plt.plot(np.arange(100, 2100, 100), timescales[i])
plt.xticks(np.arange(100, 2100, 100))
plt.xlabel('Lag time (steps, 0.5 ns / step)')
plt.ylabel('Timescale (steps, 0.5 ns / step)')
plt.yscale('log')
plt.xticks(rotation='vertical')
plt.show()

# %%
timescales_ = timescales[:6]
timescales_ = np.array(timescales)
timescales_ = timescales_[:,:6]

# %%
timescales_.shape
# Out:
# (23, 6)

# %%
plt.figure(dpi=300)
for i in range(len(timescales_)):
    plt.plot(np.arange(100, 700, 100), timescales_[i])
plt.xticks(np.arange(100, 700, 100))
plt.xlabel('Lag time (steps, 0.5 ns / step)')
plt.ylabel('Timescale (steps, 0.5 ns / step)')
plt.yscale('log')
plt.xticks(rotation='vertical')
plt.show()

# %%
# ok so this looks fine - now add confidence intervals

# %%
errors = []

for i in range(23):
    errors.append([])

for lag in lags:
    try:
        L = np.load('bayes_ck_test/%d/timescales_L.npy' % lag)
        R = np.load('bayes_ck_test/%d/timescales_R.npy' % lag)
        for i in range(23):
            try:
                errors[i].append([L[i], R[i]])
            except IndexError:
                errors[i].append([np.nan, np.nan])
    except FileNotFoundError:
        for i in range(23):
            errors[i].append([np.nan, np.nan])

# %%
# unfortunately CIs for timescales absent - forgot to add to script - rerunning now. For now switch to 6 macrostates

# %%
# 6 macrostates - 5 timescales

# %%
timescales = []

for i in range(6):
    timescales.append([])

for lag in lags:
    try:
        timescales_ = np.load('6_bayes_ck_test/%d/timescales.npy' % lag)
        for i in range(6):
            try:
                timescales[i].append(timescales_[i])
            except IndexError:
                timescales[i].append(np.nan)
    except FileNotFoundError:
        for i in range(23):
            timescales[i].append(np.nan)

# %%
plt.figure(dpi=300)
for i in range(len(timescales)):
    plt.plot(np.arange(100, 2100, 100), timescales[i])
plt.xticks(np.arange(100, 2100, 100))
plt.xlabel('Lag time (steps, 0.5 ns / step)')
plt.ylabel('Timescale (steps, 0.5 ns / step)')
plt.yscale('log')
plt.xticks(rotation='vertical')
plt.show()

# %%
timescales_ = timescales[:6]
timescales_ = np.array(timescales)
timescales_ = timescales_[:,:6]

# %%
plt.figure(dpi=300)
for i in range(len(timescales_)):
    plt.plot(np.arange(100, 700, 100), timescales_[i])
plt.xticks(np.arange(100, 700, 100))
plt.xlabel('Lag time (steps, 0.5 ns / step)')
plt.ylabel('Timescale (steps, 0.5 ns / step)')
plt.yscale('log')
plt.xticks(rotation='vertical')
plt.show()

# %%
# ok have re-run the BHMMs and got timescale CIs - back to 25 (24) macrostates

# %%
timescales = []

for i in range(23):
    timescales.append([])

for lag in lags:
    try:
        timescales_ = np.load('bayes_ck_test_2/%d/timescales.npy' % lag)
        for i in range(23):
            try:
                timescales[i].append(timescales_[i])
            except IndexError:
                timescales[i].append(np.nan)
    except FileNotFoundError:
        for i in range(23):
            timescales[i].append(np.nan)

# %%
timescales
# Out:
# [[63273.814555169956,
#   93955.421609256839,
#   110675.32788559046,
#   250470.10766778406,
#   1975414.4914748571,
#   139418.71571576849,
#   nan,
#   37618.492994938148,
#   10284.779408248556,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [31642.510020643513,
#   48248.550434413075,
#   58964.07428676304,
#   193666.54835898342,
#   102166.9037821254,
#   30410.413045022913,
#   nan,
#   267.57180474249913,
#   4789.7729358088609,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [28002.184118202091,
#   44750.045146793644,
#   33628.967891090637,
#   51418.110064260916,
#   5866.9907802181169,
#   8417.7881655692308,
#   nan,
#   nan,
#   4063.2962721506919,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [16025.413337754368,
#   16670.069283821795,
#   27415.694903819425,
#   23056.791217066337,
#   4162.2030113771389,
#   2733.4470468499021,
#   nan,
#   nan,
#   2582.3919329813425,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [15352.434574802668,
#   10266.074470390931,
#   23045.537556447591,
#   16573.090989752818,
#   2452.2620394314981,
#   1389.830185996193,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [13271.808088414607,
#   8504.1542647725873,
#   17926.504305401642,
#   15745.853177294603,
#   1349.1542722979445,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [7918.0050356738511,
#   7746.058366301495,
#   14525.801972423558,
#   12504.032511007841,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [5909.3944715856624,
#   6937.3984299924423,
#   13358.227305021102,
#   10606.696498121732,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [5460.2867444839294,
#   6573.1350775812216,
#   11271.40846544779,
#   9941.2383457895266,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [4495.5773486706385,
#   5928.8236280122774,
#   7560.6270339492239,
#   7655.1909045339844,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [3967.6705885677175,
#   5623.7468798272394,
#   5894.9079999581827,
#   7523.5839667095788,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [3704.1381738270493,
#   5366.7383716526629,
#   5813.8444498667832,
#   6093.8112560578702,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [3606.1734150241637,
#   4985.4058812569283,
#   5406.5836664202207,
#   5852.0640337083332,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [3544.4909584698962,
#   4459.6783326969162,
#   5097.1168708387522,
#   4042.5378057356525,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [3141.6577080917864,
#   4443.732710079049,
#   4221.4823436740244,
#   4035.5118771157636,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [2674.1714271972664,
#   4061.0776685226842,
#   3291.8029304804236,
#   3454.9300475676587,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [2558.3669748018224,
#   3468.0803181600377,
#   3189.790150800814,
#   2958.3579913160556,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [2388.1097507299291,
#   3317.9645770568482,
#   2811.7485719417405,
#   2816.0402667604249,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [2113.4040871537482,
#   3252.7271604464327,
#   1996.6749756583877,
#   1982.8525855491362,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [1931.3105294457212,
#   2525.003464689235,
#   1808.5506307635796,
#   1635.5261493565108,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [1763.3524979575327,
#   1896.5032458054991,
#   1238.0352201338976,
#   1132.5819221663062,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [1120.3726086310653,
#   1309.7371214081811,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [854.43364572734288,
#   1273.2733371424802,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan]]

# %%
lags
# Out:
# array([ 100,  200,  300,  400,  500,  600,  700,  800,  900, 1000, 1100,
#        1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000])

# %%
timescales = []

for i in range(23):
    timescales.append([])

errors = []

for i in range(23):
    errors.append([])

for lag in lags:
    try:
        L = np.load('bayes_ck_test_2/%d/timescales_L.npy' % lag)
        R = np.load('bayes_ck_test_2/%d/timescales_R.npy' % lag)
        timescales_ = np.load('bayes_ck_test_2/%d/timescales.npy' % lag)
        for i in range(23):
            try:
                if not (L[i] == np.nan or R[i] == np.nan or timescales_[i] == np.nan):
                    errors[i].append([timescales_[i] - L[i], R[i] - timescales_[i]])
                    timescales[i].append(timescales_[i])
                else:
                    timescales[i].append(np.nan)
                    errors[i].append([np.nan, np.nan])
            except IndexError:
                timescales[i].append(np.nan)
                errors[i].append([np.nan, np.nan])
    except FileNotFoundError:
        for i in range(23):
            timescales[i].append(np.nan)
            errors[i].append([np.nan, np.nan])

# %%
plt.figure(dpi=300)
for i in range(len(timescales)):
    plt.errorbar(np.arange(100, 2100, 100), timescales[i], yerr=np.array(errors[i]).transpose())
plt.xticks(np.arange(100, 2100, 100))
plt.xlabel('Lag time (steps, 0.5 ns / step)')
plt.ylabel('Timescale (steps, 0.5 ns / step)')
plt.yscale('log')
plt.xticks(rotation='vertical')
plt.show()

# %%
# ok now plot this only up to lag 600

# %%
timescales_ = timescales[:6]
timescales_ = np.array(timescales)
timescales_ = timescales_[:,:6]

# %%
errors_ = errors[:6]
errors_ = np.array(errors)
errors_ = errors_[:,:6]

# %%
plt.figure(dpi=300)
for i in range(len(timescales_)):
    plt.errorbar(np.arange(100, 700, 100), timescales_[i], yerr=np.array(errors_[i]).transpose())
plt.xticks(np.arange(100, 700, 100))
plt.xlabel('Lag time (steps, 0.5 ns / step)')
plt.ylabel('Timescale (steps, 0.5 ns / step)')
plt.yscale('log')
plt.xticks(rotation='vertical')
plt.show()

# %%
# and decrease the yrange to see more

# %%
plt.figure(dpi=300)
for i in range(len(timescales_)):
    plt.errorbar(np.arange(100, 700, 100), timescales_[i], yerr=np.array(errors_[i]).transpose())
plt.xticks(np.arange(100, 700, 100))
plt.xlabel('Lag time (steps, 0.5 ns / step)')
plt.ylabel('Timescale (steps, 0.5 ns / step)')
plt.yscale('log')
plt.ylim(6e2, 1e7)
plt.xticks(rotation='vertical')
plt.show()

# %%
# now plot only some timescales

# %%
for j in range(23):    
    plt.figure(dpi=300)
    for i in [j]:
        plt.errorbar(np.arange(100, 700, 100), timescales_[i], yerr=np.array(errors_[i]).transpose())
    plt.xticks(np.arange(100, 700, 100))
    plt.xlabel('Lag time (steps, 0.5 ns / step)')
    plt.ylabel('Timescale (steps, 0.5 ns / step)')
    plt.yscale('log')
    plt.ylim(6e2, 1e7)
    plt.xticks(rotation='vertical')
    plt.savefig('hmm25_bayesian_plots/%d.png' % i, dpi=300)
    plt.close()

# %%
plt.figure(dpi=300)
for i in [8]:
    plt.errorbar(np.arange(100, 700, 100), timescales_[i], yerr=np.array(errors_[i]).transpose())
plt.xticks(np.arange(100, 700, 100))
plt.xlabel('Lag time (steps, 0.5 ns / step)')
plt.ylabel('Timescale (steps, 0.5 ns / step)')
plt.yscale('log')
plt.ylim(6e2, 1e7)
plt.xticks(rotation='vertical')
plt.show()

# %%
timescales_[8]
# Out:
# array([  5460.28674448,   6573.13507758,  11271.40846545,   9941.23834579,
#                    nan,             nan])

# %%
errors_[8]
# Out:
# array([[ 1962.42370957,   719.98455043],
#        [ 2247.1628817 ,   278.45561208],
#        [ 6396.40170305, -1415.76689618],
#        [ 5066.05207488,   864.60202293],
#        [           nan,            nan],
#        [           nan,            nan]])

# %%
np.array(errors_[8]).transpose()
# Out:
# array([[ 1962.42370957,  2247.1628817 ,  6396.40170305,  5066.05207488,
#                    nan,            nan],
#        [  719.98455043,   278.45561208, -1415.76689618,   864.60202293,
#                    nan,            nan]])

# %%
lag = 300

L = np.load('bayes_ck_test_2/%d/timescales_L.npy' % lag)
R = np.load('bayes_ck_test_2/%d/timescales_R.npy' % lag)
timescales_ = np.load('bayes_ck_test_2/%d/timescales.npy' % lag)

# %%
timescales_[8]
# Out:
# 11271.40846544779

# %%
L[8]
# Out:
# 4875.0067623960304

# %%
R[8]
# Out:
# 9855.6415692690243

# %%
# WEIRD

# %%
# ok now do 6 macrostates with CIs

# %%
timescales = []

for i in range(23):
    timescales.append([])

errors = []

for i in range(23):
    errors.append([])

for lag in lags:
    try:
        L = np.load('6_bayes_ck_test_2/%d/timescales_L.npy' % lag)
        R = np.load('6_bayes_ck_test_2/%d/timescales_R.npy' % lag)
        timescales_ = np.load('6_bayes_ck_test_2/%d/timescales.npy' % lag)
        for i in range(23):
            try:
                if not (L[i] == np.nan or R[i] == np.nan or timescales_[i] == np.nan):
                    errors[i].append([timescales_[i] - L[i], R[i] - timescales_[i]])
                    timescales[i].append(timescales_[i])
                else:
                    timescales[i].append(np.nan)
                    errors[i].append([np.nan, np.nan])
            except IndexError:
                timescales[i].append(np.nan)
                errors[i].append([np.nan, np.nan])
    except FileNotFoundError:
        for i in range(23):
            timescales[i].append(np.nan)
            errors[i].append([np.nan, np.nan])

# %%
plt.figure(dpi=300)
for i in range(len(timescales)):
    plt.errorbar(np.arange(100, 2100, 100), timescales[i], yerr=np.array(errors[i]).transpose())
plt.xticks(np.arange(100, 2100, 100))
plt.xlabel('Lag time (steps, 0.5 ns / step)')
plt.ylabel('Timescale (steps, 0.5 ns / step)')
plt.yscale('log')
plt.xticks(rotation='vertical')
plt.show()
